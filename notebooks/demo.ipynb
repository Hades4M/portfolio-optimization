# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
sys.path.insert(0, str(project_root))

# %%
from src.loader import (
    load_history,
    load_close_prices,
)

from src.returns import calculate_returns

from src.metrics import (
    calculate_annual_return,
    calculate_annual_volatility,
    calculate_covariance_matrix,
)

from src.optimizer import optimize_portfolio
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 14
#       6 from src.returns import calculate_returns
#       8 from src.metrics import (
#       9     calculate_annual_return,
#      10     calculate_annual_volatility,
#      11     calculate_covariance_matrix,
#      12 )
# ---> 14 from src.optimizer import optimize_portfolio
#
# File c:\Users\user\Projects\portfolio-optimization\src\optimizer.py:4
#       1 import numpy as np
#       2 import pandas as pd
# ----> 4 from scipy.optimize import minimize
#       7 def _portfolio_return(
#       8     weights: np.ndarray,
#       9     expected_returns: pd.Series,
#      10 ) -> float:
#      11     """
#      12     Calculate expected annual portfolio return.
#      13
#    (...)     24         Expected portfolio return.
#      25     """
#
# ModuleNotFoundError: No module named 'scipy'
